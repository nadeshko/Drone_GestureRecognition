# %% [markdown]
# # Imports and Dependencies

# %%
from google.colab.patches import cv2_imshow
import numpy as np
import cv2
import os
# mount google drive
from google.colab import drive
drive.mount('/content/gdrive')
os.chdir("/content/gdrive/My Drive/Drone_Recog/")
# Out:
# Mounted at /content/gdrive

# %%
vid_path = 'datasets/Videos'
img_path = 'datasets/Images'
OF_path = 'datasets/OF'
OF_Dense_path = 'datasets/OFDense'

# %% [markdown]
# # Farneback

# %%
# get classes from frames path
class_names = os.listdir(img_path)
for cname in class_names:
    video_dir = os.listdir(os.path.join(img_path, cname))
    if cname == 'waving_hands':
        for videos in video_dir:
            vidframe_path = os.path.join(img_path, cname, videos)
            vid_frames = os.listdir(vidframe_path)
            frame_count = len(vid_frames)
            print(f'computing OF in {videos}')
            for i in range(frame_count-1): # get optical flow between frames
                # get current and next frame and convert them to gray
                # because flow input only accepts 8-bit single channel
                f1 = cv2.imread(f'{vidframe_path}/{vid_frames[i]}')
                f1 = cv2.cvtColor(f1, cv2.COLOR_RGB2GRAY) 
                f2 = cv2.imread(f'{vidframe_path}/{vid_frames[i+1]}')
                f2 = cv2.cvtColor(f2, cv2.COLOR_RGB2GRAY)

                # create image filled with zeros and set saturation to max
                mask = np.zeros((1080, 1920, 3), dtype=np.uint8)
                mask[:, :, 0] = 255
                mask[:, :, 1] = 255

                # show images
                #cv2_imshow(f1)
                #cv2_imshow(f2)

                # calculate dense optical flow with farnebeck method
                flow = None
                flow = cv2.calcOpticalFlowFarneback(f1, f2, 
                                                    None, # flow (change in motion between frames)
                                                    pyr_scale = 0.5, levels = 3, winsize = 15, 
                                                    iterations = 3, poly_n = 10, poly_sigma = 2.5, 
                                                    flags = 0)
                # pyr  : img scale to build pyramids for each img
                # lvls : no. of pyramid layers
                # winsz: larger increases robustness to noise for fast motion detection, more blurry
                # iter : no. of iter at each pyramid lvl
                # polyn: sz of pixel neighbourhood used to find polynomial expansion in each pixel  
                # polys: smooths derivatives for polynomial expansion
                # flags: operational flags
                
                # compute angle and magnitude of 2D vectors
                mag, ang = cv2.cartToPolar(flow[..., 0], flow[..., 1])

                # set img hue according to OF direction
                mask[..., 0] = ang * 180 / np.pi / 2
                # set img value to OF magnitude (normalized)
                mask[..., 2] = cv2.normalize(mag, None, 0, 255, cv2.NORM_MINMAX)

                # Converts HSV to RGB (BGR) color representation
                rgb = cv2.cvtColor(mask, cv2.COLOR_HSV2BGR)
                rgb = cv2.resize(rgb, (360, 240))

                # show output frame
                #cv2_imshow(rgb)

                OFframe_path = os.path.join(OF_path, cname, videos)
                OFframe_name = f'{os.path.splitext(videos)[0]}_OFframe_{i}.jpeg'
                print(OFframe_name)
                if not os.path.exists(OFframe_path):
                    print(f'creating directory {OFframe_path}')
                    os.makedirs(OFframe_path)
                cv2.imwrite(f'{OFframe_path}/{OFframe_name}', rgb)
# Out:
# computing OF in S2_wavingHands_HD
# S2_wavingHands_HD_OFframe_0.jpeg
# creating directory datasets/OF/waving_hands/S2_wavingHands_HD
# S2_wavingHands_HD_OFframe_1.jpeg
# S2_wavingHands_HD_OFframe_2.jpeg
# S2_wavingHands_HD_OFframe_3.jpeg
# S2_wavingHands_HD_OFframe_4.jpeg
# S2_wavingHands_HD_OFframe_5.jpeg
# S2_wavingHands_HD_OFframe_6.jpeg
# S2_wavingHands_HD_OFframe_7.jpeg
# S2_wavingHands_HD_OFframe_8.jpeg
# S2_wavingHands_HD_OFframe_9.jpeg
# S2_wavingHands_HD_OFframe_10.jpeg
# S2_wavingHands_HD_OFframe_11.jpeg
# S2_wavingHands_HD_OFframe_12.jpeg
# S2_wavingHands_HD_OFframe_13.jpeg
# S2_wavingHands_HD_OFframe_14.jpeg
# S2_wavingHands_HD_OFframe_15.jpeg
# S2_wavingHands_HD_OFframe_16.jpeg
# S2_wavingHands_HD_OFframe_17.jpeg
# S2_wavingHands_HD_OFframe_18.jpeg
# S2_wavingHands_HD_OFframe_19.jpeg
# S2_wavingHands_HD_OFframe_20.jpeg
# S2_wavingHands_HD_OFframe_21.jpeg
# S2_wavingHands_HD_OFframe_22.jpeg
# S2_wavingHands_HD_OFframe_23.jpeg
# S2_wavingHands_HD_OFframe_24.jpeg
# S2_wavingHands_HD_OFframe_25.jpeg
# S2_wavingHands_HD_OFframe_26.jpeg
# S2_wavingHands_HD_OFframe_27.jpeg
# S2_wavingHands_HD_OFframe_28.jpeg
# S2_wavingHands_HD_OFframe_29.jpeg
# S2_wavingHands_HD_OFframe_30.jpeg
# S2_wavingHands_HD_OFframe_31.jpeg
# S2_wavingHands_HD_OFframe_32.jpeg
# S2_wavingHands_HD_OFframe_33.jpeg
# S2_wavingHands_HD_OFframe_34.jpeg
# S2_wavingHands_HD_OFframe_35.jpeg
# S2_wavingHands_HD_OFframe_36.jpeg
# S2_wavingHands_HD_OFframe_37.jpeg
# S2_wavingHands_HD_OFframe_38.jpeg
# S2_wavingHands_HD_OFframe_39.jpeg
# S2_wavingHands_HD_OFframe_40.jpeg
# S2_wavingHands_HD_OFframe_41.jpeg
# S2_wavingHands_HD_OFframe_42.jpeg
# S2_wavingHands_HD_OFframe_43.jpeg
# S2_wavingHands_HD_OFframe_44.jpeg
# S2_wavingHands_HD_OFframe_45.jpeg
# S2_wavingHands_HD_OFframe_46.jpeg
# S2_wavingHands_HD_OFframe_47.jpeg
# S2_wavingHands_HD_OFframe_48.jpeg
# S2_wavingHands_HD_OFframe_49.jpeg
# computing OF in S10_wavingHands_HD
# S10_wavingHands_HD_OFframe_0.jpeg
# creating directory datasets/OF/waving_hands/S10_wavingHands_HD
# S10_wavingHands_HD_OFframe_1.jpeg
# S10_wavingHands_HD_OFframe_2.jpeg
# S10_wavingHands_HD_OFframe_3.jpeg
# S10_wavingHands_HD_OFframe_4.jpeg
# S10_wavingHands_HD_OFframe_5.jpeg
# S10_wavingHands_HD_OFframe_6.jpeg
# S10_wavingHands_HD_OFframe_7.jpeg
# S10_wavingHands_HD_OFframe_8.jpeg
# S10_wavingHands_HD_OFframe_9.jpeg
# S10_wavingHands_HD_OFframe_10.jpeg
# S10_wavingHands_HD_OFframe_11.jpeg
# S10_wavingHands_HD_OFframe_12.jpeg
# S10_wavingHands_HD_OFframe_13.jpeg
# S10_wavingHands_HD_OFframe_14.jpeg
# S10_wavingHands_HD_OFframe_15.jpeg
# S10_wavingHands_HD_OFframe_16.jpeg
# S10_wavingHands_HD_OFframe_17.jpeg
# S10_wavingHands_HD_OFframe_18.jpeg
# S10_wavingHands_HD_OFframe_19.jpeg
# S10_wavingHands_HD_OFframe_20.jpeg
# S10_wavingHands_HD_OFframe_21.jpeg
# S10_wavingHands_HD_OFframe_22.jpeg
# S10_wavingHands_HD_OFframe_23.jpeg
# S10_wavingHands_HD_OFframe_24.jpeg
# S10_wavingHands_HD_OFframe_25.jpeg
# S10_wavingHands_HD_OFframe_26.jpeg
# S10_wavingHands_HD_OFframe_27.jpeg
# S10_wavingHands_HD_OFframe_28.jpeg
# S10_wavingHands_HD_OFframe_29.jpeg
# S10_wavingHands_HD_OFframe_30.jpeg
# S10_wavingHands_HD_OFframe_31.jpeg
# S10_wavingHands_HD_OFframe_32.jpeg
# S10_wavingHands_HD_OFframe_33.jpeg
# S10_wavingHands_HD_OFframe_34.jpeg
# S10_wavingHands_HD_OFframe_35.jpeg
# S10_wavingHands_HD_OFframe_36.jpeg
# S10_wavingHands_HD_OFframe_37.jpeg
# S10_wavingHands_HD_OFframe_38.jpeg
# S10_wavingHands_HD_OFframe_39.jpeg
# S10_wavingHands_HD_OFframe_40.jpeg
# S10_wavingHands_HD_OFframe_41.jpeg
# S10_wavingHands_HD_OFframe_42.jpeg
# S10_wavingHands_HD_OFframe_43.jpeg
# S10_wavingHands_HD_OFframe_44.jpeg
# S10_wavingHands_HD_OFframe_45.jpeg
# S10_wavingHands_HD_OFframe_46.jpeg
# S10_wavingHands_HD_OFframe_47.jpeg
# S10_wavingHands_HD_OFframe_48.jpeg
# S10_wavingHands_HD_OFframe_49.jpeg
# computing OF in S9_wavingHands_HD
# S9_wavingHands_HD_OFframe_0.jpeg
# creating directory datasets/OF/waving_hands/S9_wavingHands_HD
# S9_wavingHands_HD_OFframe_1.jpeg
# S9_wavingHands_HD_OFframe_2.jpeg
# S9_wavingHands_HD_OFframe_3.jpeg
# S9_wavingHands_HD_OFframe_4.jpeg
# S9_wavingHands_HD_OFframe_5.jpeg
# S9_wavingHands_HD_OFframe_6.jpeg
# S9_wavingHands_HD_OFframe_7.jpeg
# S9_wavingHands_HD_OFframe_8.jpeg
# S9_wavingHands_HD_OFframe_9.jpeg
# S9_wavingHands_HD_OFframe_10.jpeg
# S9_wavingHands_HD_OFframe_11.jpeg
# S9_wavingHands_HD_OFframe_12.jpeg
# S9_wavingHands_HD_OFframe_13.jpeg
# S9_wavingHands_HD_OFframe_14.jpeg
# S9_wavingHands_HD_OFframe_15.jpeg
# S9_wavingHands_HD_OFframe_16.jpeg
# S9_wavingHands_HD_OFframe_17.jpeg
# S9_wavingHands_HD_OFframe_18.jpeg
# S9_wavingHands_HD_OFframe_19.jpeg
# S9_wavingHands_HD_OFframe_20.jpeg
# S9_wavingHands_HD_OFframe_21.jpeg
# S9_wavingHands_HD_OFframe_22.jpeg
# S9_wavingHands_HD_OFframe_23.jpeg
# S9_wavingHands_HD_OFframe_24.jpeg
# S9_wavingHands_HD_OFframe_25.jpeg
# S9_wavingHands_HD_OFframe_26.jpeg
# S9_wavingHands_HD_OFframe_27.jpeg
# S9_wavingHands_HD_OFframe_28.jpeg
# S9_wavingHands_HD_OFframe_29.jpeg
# S9_wavingHands_HD_OFframe_30.jpeg
# S9_wavingHands_HD_OFframe_31.jpeg
# S9_wavingHands_HD_OFframe_32.jpeg
# S9_wavingHands_HD_OFframe_33.jpeg
# S9_wavingHands_HD_OFframe_34.jpeg
# S9_wavingHands_HD_OFframe_35.jpeg
# S9_wavingHands_HD_OFframe_36.jpeg
# S9_wavingHands_HD_OFframe_37.jpeg
# S9_wavingHands_HD_OFframe_38.jpeg
# S9_wavingHands_HD_OFframe_39.jpeg
# S9_wavingHands_HD_OFframe_40.jpeg
# S9_wavingHands_HD_OFframe_41.jpeg
# S9_wavingHands_HD_OFframe_42.jpeg
# S9_wavingHands_HD_OFframe_43.jpeg
# S9_wavingHands_HD_OFframe_44.jpeg
# S9_wavingHands_HD_OFframe_45.jpeg
# S9_wavingHands_HD_OFframe_46.jpeg
# S9_wavingHands_HD_OFframe_47.jpeg
# S9_wavingHands_HD_OFframe_48.jpeg
# S9_wavingHands_HD_OFframe_49.jpeg
# computing OF in S8_wavingHands_HD
# S8_wavingHands_HD_OFframe_0.jpeg
# creating directory datasets/OF/waving_hands/S8_wavingHands_HD
# S8_wavingHands_HD_OFframe_1.jpeg
# S8_wavingHands_HD_OFframe_2.jpeg
# S8_wavingHands_HD_OFframe_3.jpeg
# S8_wavingHands_HD_OFframe_4.jpeg
# S8_wavingHands_HD_OFframe_5.jpeg
# S8_wavingHands_HD_OFframe_6.jpeg
# S8_wavingHands_HD_OFframe_7.jpeg
# S8_wavingHands_HD_OFframe_8.jpeg
# S8_wavingHands_HD_OFframe_9.jpeg
# S8_wavingHands_HD_OFframe_10.jpeg
# S8_wavingHands_HD_OFframe_11.jpeg
# S8_wavingHands_HD_OFframe_12.jpeg
# S8_wavingHands_HD_OFframe_13.jpeg
# S8_wavingHands_HD_OFframe_14.jpeg
# S8_wavingHands_HD_OFframe_15.jpeg
# S8_wavingHands_HD_OFframe_16.jpeg
# S8_wavingHands_HD_OFframe_17.jpeg
# S8_wavingHands_HD_OFframe_18.jpeg
# S8_wavingHands_HD_OFframe_19.jpeg
# S8_wavingHands_HD_OFframe_20.jpeg
# S8_wavingHands_HD_OFframe_21.jpeg
# S8_wavingHands_HD_OFframe_22.jpeg
# S8_wavingHands_HD_OFframe_23.jpeg
# S8_wavingHands_HD_OFframe_24.jpeg
# S8_wavingHands_HD_OFframe_25.jpeg
# S8_wavingHands_HD_OFframe_26.jpeg
# S8_wavingHands_HD_OFframe_27.jpeg
# S8_wavingHands_HD_OFframe_28.jpeg
# S8_wavingHands_HD_OFframe_29.jpeg
# S8_wavingHands_HD_OFframe_30.jpeg
# S8_wavingHands_HD_OFframe_31.jpeg
# S8_wavingHands_HD_OFframe_32.jpeg
# S8_wavingHands_HD_OFframe_33.jpeg
# S8_wavingHands_HD_OFframe_34.jpeg
# S8_wavingHands_HD_OFframe_35.jpeg
# S8_wavingHands_HD_OFframe_36.jpeg
# S8_wavingHands_HD_OFframe_37.jpeg
# S8_wavingHands_HD_OFframe_38.jpeg
# S8_wavingHands_HD_OFframe_39.jpeg
# S8_wavingHands_HD_OFframe_40.jpeg
# S8_wavingHands_HD_OFframe_41.jpeg
# S8_wavingHands_HD_OFframe_42.jpeg
# S8_wavingHands_HD_OFframe_43.jpeg
# S8_wavingHands_HD_OFframe_44.jpeg
# S8_wavingHands_HD_OFframe_45.jpeg
# S8_wavingHands_HD_OFframe_46.jpeg
# S8_wavingHands_HD_OFframe_47.jpeg
# S8_wavingHands_HD_OFframe_48.jpeg
# S8_wavingHands_HD_OFframe_49.jpeg
# computing OF in S7_wavingHands_HD
# S7_wavingHands_HD_OFframe_0.jpeg
# creating directory datasets/OF/waving_hands/S7_wavingHands_HD
# S7_wavingHands_HD_OFframe_1.jpeg
# S7_wavingHands_HD_OFframe_2.jpeg
# S7_wavingHands_HD_OFframe_3.jpeg
# S7_wavingHands_HD_OFframe_4.jpeg
# S7_wavingHands_HD_OFframe_5.jpeg
# S7_wavingHands_HD_OFframe_6.jpeg
# S7_wavingHands_HD_OFframe_7.jpeg
# S7_wavingHands_HD_OFframe_8.jpeg
# S7_wavingHands_HD_OFframe_9.jpeg
# S7_wavingHands_HD_OFframe_10.jpeg
# S7_wavingHands_HD_OFframe_11.jpeg
# S7_wavingHands_HD_OFframe_12.jpeg
# S7_wavingHands_HD_OFframe_13.jpeg
# S7_wavingHands_HD_OFframe_14.jpeg
# S7_wavingHands_HD_OFframe_15.jpeg
# S7_wavingHands_HD_OFframe_16.jpeg
# S7_wavingHands_HD_OFframe_17.jpeg
# S7_wavingHands_HD_OFframe_18.jpeg
# S7_wavingHands_HD_OFframe_19.jpeg
# S7_wavingHands_HD_OFframe_20.jpeg
# S7_wavingHands_HD_OFframe_21.jpeg
# S7_wavingHands_HD_OFframe_22.jpeg
# S7_wavingHands_HD_OFframe_23.jpeg
# S7_wavingHands_HD_OFframe_24.jpeg
# S7_wavingHands_HD_OFframe_25.jpeg
# S7_wavingHands_HD_OFframe_26.jpeg
# S7_wavingHands_HD_OFframe_27.jpeg
# S7_wavingHands_HD_OFframe_28.jpeg
# S7_wavingHands_HD_OFframe_29.jpeg
# S7_wavingHands_HD_OFframe_30.jpeg
# S7_wavingHands_HD_OFframe_31.jpeg
# S7_wavingHands_HD_OFframe_32.jpeg
# S7_wavingHands_HD_OFframe_33.jpeg
# S7_wavingHands_HD_OFframe_34.jpeg
# S7_wavingHands_HD_OFframe_35.jpeg
# S7_wavingHands_HD_OFframe_36.jpeg
# S7_wavingHands_HD_OFframe_37.jpeg
# S7_wavingHands_HD_OFframe_38.jpeg
# S7_wavingHands_HD_OFframe_39.jpeg
# S7_wavingHands_HD_OFframe_40.jpeg
# S7_wavingHands_HD_OFframe_41.jpeg
# S7_wavingHands_HD_OFframe_42.jpeg
# S7_wavingHands_HD_OFframe_43.jpeg
# S7_wavingHands_HD_OFframe_44.jpeg
# S7_wavingHands_HD_OFframe_45.jpeg
# S7_wavingHands_HD_OFframe_46.jpeg
# S7_wavingHands_HD_OFframe_47.jpeg
# S7_wavingHands_HD_OFframe_48.jpeg
# S7_wavingHands_HD_OFframe_49.jpeg
# computing OF in S6_wavingHands_HD
# S6_wavingHands_HD_OFframe_0.jpeg
# creating directory datasets/OF/waving_hands/S6_wavingHands_HD
# S6_wavingHands_HD_OFframe_1.jpeg
# S6_wavingHands_HD_OFframe_2.jpeg
# S6_wavingHands_HD_OFframe_3.jpeg
# S6_wavingHands_HD_OFframe_4.jpeg
# S6_wavingHands_HD_OFframe_5.jpeg
# S6_wavingHands_HD_OFframe_6.jpeg
# S6_wavingHands_HD_OFframe_7.jpeg
# S6_wavingHands_HD_OFframe_8.jpeg
# S6_wavingHands_HD_OFframe_9.jpeg
# S6_wavingHands_HD_OFframe_10.jpeg
# S6_wavingHands_HD_OFframe_11.jpeg
# S6_wavingHands_HD_OFframe_12.jpeg
# S6_wavingHands_HD_OFframe_13.jpeg
# S6_wavingHands_HD_OFframe_14.jpeg
# S6_wavingHands_HD_OFframe_15.jpeg
# S6_wavingHands_HD_OFframe_16.jpeg
# S6_wavingHands_HD_OFframe_17.jpeg
# S6_wavingHands_HD_OFframe_18.jpeg
# S6_wavingHands_HD_OFframe_19.jpeg
# S6_wavingHands_HD_OFframe_20.jpeg
# S6_wavingHands_HD_OFframe_21.jpeg
# S6_wavingHands_HD_OFframe_22.jpeg
# S6_wavingHands_HD_OFframe_23.jpeg
# S6_wavingHands_HD_OFframe_24.jpeg
# S6_wavingHands_HD_OFframe_25.jpeg
# S6_wavingHands_HD_OFframe_26.jpeg
# S6_wavingHands_HD_OFframe_27.jpeg
# S6_wavingHands_HD_OFframe_28.jpeg
# S6_wavingHands_HD_OFframe_29.jpeg
# S6_wavingHands_HD_OFframe_30.jpeg
# S6_wavingHands_HD_OFframe_31.jpeg
# S6_wavingHands_HD_OFframe_32.jpeg
# S6_wavingHands_HD_OFframe_33.jpeg
# S6_wavingHands_HD_OFframe_34.jpeg
# S6_wavingHands_HD_OFframe_35.jpeg
# S6_wavingHands_HD_OFframe_36.jpeg
# S6_wavingHands_HD_OFframe_37.jpeg
# S6_wavingHands_HD_OFframe_38.jpeg
# S6_wavingHands_HD_OFframe_39.jpeg
# S6_wavingHands_HD_OFframe_40.jpeg
# S6_wavingHands_HD_OFframe_41.jpeg
# S6_wavingHands_HD_OFframe_42.jpeg
# S6_wavingHands_HD_OFframe_43.jpeg
# S6_wavingHands_HD_OFframe_44.jpeg
# S6_wavingHands_HD_OFframe_45.jpeg
# S6_wavingHands_HD_OFframe_46.jpeg
# S6_wavingHands_HD_OFframe_47.jpeg
# S6_wavingHands_HD_OFframe_48.jpeg
# S6_wavingHands_HD_OFframe_49.jpeg
# computing OF in S5_wavingHands_HD
# S5_wavingHands_HD_OFframe_0.jpeg
# creating directory datasets/OF/waving_hands/S5_wavingHands_HD
# S5_wavingHands_HD_OFframe_1.jpeg
# S5_wavingHands_HD_OFframe_2.jpeg
# S5_wavingHands_HD_OFframe_3.jpeg
# S5_wavingHands_HD_OFframe_4.jpeg
# S5_wavingHands_HD_OFframe_5.jpeg
# S5_wavingHands_HD_OFframe_6.jpeg
# S5_wavingHands_HD_OFframe_7.jpeg
# S5_wavingHands_HD_OFframe_8.jpeg
# S5_wavingHands_HD_OFframe_9.jpeg
# S5_wavingHands_HD_OFframe_10.jpeg
# S5_wavingHands_HD_OFframe_11.jpeg
# S5_wavingHands_HD_OFframe_12.jpeg
# S5_wavingHands_HD_OFframe_13.jpeg
# S5_wavingHands_HD_OFframe_14.jpeg
# S5_wavingHands_HD_OFframe_15.jpeg
# S5_wavingHands_HD_OFframe_16.jpeg
# S5_wavingHands_HD_OFframe_17.jpeg
# S5_wavingHands_HD_OFframe_18.jpeg
# S5_wavingHands_HD_OFframe_19.jpeg
# S5_wavingHands_HD_OFframe_20.jpeg
# S5_wavingHands_HD_OFframe_21.jpeg
# S5_wavingHands_HD_OFframe_22.jpeg
# S5_wavingHands_HD_OFframe_23.jpeg
# S5_wavingHands_HD_OFframe_24.jpeg
# S5_wavingHands_HD_OFframe_25.jpeg
# S5_wavingHands_HD_OFframe_26.jpeg
# S5_wavingHands_HD_OFframe_27.jpeg
# S5_wavingHands_HD_OFframe_28.jpeg
# S5_wavingHands_HD_OFframe_29.jpeg
# S5_wavingHands_HD_OFframe_30.jpeg
# S5_wavingHands_HD_OFframe_31.jpeg
# S5_wavingHands_HD_OFframe_32.jpeg
# S5_wavingHands_HD_OFframe_33.jpeg
# S5_wavingHands_HD_OFframe_34.jpeg
# S5_wavingHands_HD_OFframe_35.jpeg
# S5_wavingHands_HD_OFframe_36.jpeg
# S5_wavingHands_HD_OFframe_37.jpeg
# S5_wavingHands_HD_OFframe_38.jpeg
# S5_wavingHands_HD_OFframe_39.jpeg
# S5_wavingHands_HD_OFframe_40.jpeg
# S5_wavingHands_HD_OFframe_41.jpeg
# S5_wavingHands_HD_OFframe_42.jpeg
# S5_wavingHands_HD_OFframe_43.jpeg
# S5_wavingHands_HD_OFframe_44.jpeg
# S5_wavingHands_HD_OFframe_45.jpeg
# S5_wavingHands_HD_OFframe_46.jpeg
# S5_wavingHands_HD_OFframe_47.jpeg
# S5_wavingHands_HD_OFframe_48.jpeg
# S5_wavingHands_HD_OFframe_49.jpeg
# computing OF in S4_wavingHands_HD
# S4_wavingHands_HD_OFframe_0.jpeg
# creating directory datasets/OF/waving_hands/S4_wavingHands_HD
# S4_wavingHands_HD_OFframe_1.jpeg
# S4_wavingHands_HD_OFframe_2.jpeg
# S4_wavingHands_HD_OFframe_3.jpeg
# S4_wavingHands_HD_OFframe_4.jpeg
# S4_wavingHands_HD_OFframe_5.jpeg
# S4_wavingHands_HD_OFframe_6.jpeg
# S4_wavingHands_HD_OFframe_7.jpeg
# S4_wavingHands_HD_OFframe_8.jpeg
# S4_wavingHands_HD_OFframe_9.jpeg
# S4_wavingHands_HD_OFframe_10.jpeg
# S4_wavingHands_HD_OFframe_11.jpeg
# S4_wavingHands_HD_OFframe_12.jpeg
# S4_wavingHands_HD_OFframe_13.jpeg
# S4_wavingHands_HD_OFframe_14.jpeg
# S4_wavingHands_HD_OFframe_15.jpeg
# S4_wavingHands_HD_OFframe_16.jpeg
# S4_wavingHands_HD_OFframe_17.jpeg
# S4_wavingHands_HD_OFframe_18.jpeg
# S4_wavingHands_HD_OFframe_19.jpeg
# S4_wavingHands_HD_OFframe_20.jpeg
# S4_wavingHands_HD_OFframe_21.jpeg
# S4_wavingHands_HD_OFframe_22.jpeg
# S4_wavingHands_HD_OFframe_23.jpeg
# S4_wavingHands_HD_OFframe_24.jpeg
# S4_wavingHands_HD_OFframe_25.jpeg
# S4_wavingHands_HD_OFframe_26.jpeg
# S4_wavingHands_HD_OFframe_27.jpeg
# S4_wavingHands_HD_OFframe_28.jpeg
# S4_wavingHands_HD_OFframe_29.jpeg
# S4_wavingHands_HD_OFframe_30.jpeg
# S4_wavingHands_HD_OFframe_31.jpeg
# S4_wavingHands_HD_OFframe_32.jpeg
# S4_wavingHands_HD_OFframe_33.jpeg
# S4_wavingHands_HD_OFframe_34.jpeg
# S4_wavingHands_HD_OFframe_35.jpeg
# S4_wavingHands_HD_OFframe_36.jpeg
# S4_wavingHands_HD_OFframe_37.jpeg
# S4_wavingHands_HD_OFframe_38.jpeg
# S4_wavingHands_HD_OFframe_39.jpeg
# S4_wavingHands_HD_OFframe_40.jpeg
# S4_wavingHands_HD_OFframe_41.jpeg
# S4_wavingHands_HD_OFframe_42.jpeg
# S4_wavingHands_HD_OFframe_43.jpeg
# S4_wavingHands_HD_OFframe_44.jpeg
# S4_wavingHands_HD_OFframe_45.jpeg
# S4_wavingHands_HD_OFframe_46.jpeg
# S4_wavingHands_HD_OFframe_47.jpeg
# S4_wavingHands_HD_OFframe_48.jpeg
# S4_wavingHands_HD_OFframe_49.jpeg
# computing OF in S3_wavingHands_HD
# S3_wavingHands_HD_OFframe_0.jpeg
# creating directory datasets/OF/waving_hands/S3_wavingHands_HD
# S3_wavingHands_HD_OFframe_1.jpeg
# S3_wavingHands_HD_OFframe_2.jpeg
# S3_wavingHands_HD_OFframe_3.jpeg
# S3_wavingHands_HD_OFframe_4.jpeg
# S3_wavingHands_HD_OFframe_5.jpeg
# S3_wavingHands_HD_OFframe_6.jpeg
# S3_wavingHands_HD_OFframe_7.jpeg
# S3_wavingHands_HD_OFframe_8.jpeg
# S3_wavingHands_HD_OFframe_9.jpeg
# S3_wavingHands_HD_OFframe_10.jpeg
# S3_wavingHands_HD_OFframe_11.jpeg
# S3_wavingHands_HD_OFframe_12.jpeg
# S3_wavingHands_HD_OFframe_13.jpeg
# S3_wavingHands_HD_OFframe_14.jpeg
# S3_wavingHands_HD_OFframe_15.jpeg
# S3_wavingHands_HD_OFframe_16.jpeg
# S3_wavingHands_HD_OFframe_17.jpeg
# S3_wavingHands_HD_OFframe_18.jpeg
# S3_wavingHands_HD_OFframe_19.jpeg
# S3_wavingHands_HD_OFframe_20.jpeg
# S3_wavingHands_HD_OFframe_21.jpeg
# S3_wavingHands_HD_OFframe_22.jpeg
# S3_wavingHands_HD_OFframe_23.jpeg
# S3_wavingHands_HD_OFframe_24.jpeg
# S3_wavingHands_HD_OFframe_25.jpeg
# S3_wavingHands_HD_OFframe_26.jpeg
# S3_wavingHands_HD_OFframe_27.jpeg
# S3_wavingHands_HD_OFframe_28.jpeg
# S3_wavingHands_HD_OFframe_29.jpeg
# S3_wavingHands_HD_OFframe_30.jpeg
# S3_wavingHands_HD_OFframe_31.jpeg
# S3_wavingHands_HD_OFframe_32.jpeg
# S3_wavingHands_HD_OFframe_33.jpeg
# S3_wavingHands_HD_OFframe_34.jpeg
# S3_wavingHands_HD_OFframe_35.jpeg
# S3_wavingHands_HD_OFframe_36.jpeg
# S3_wavingHands_HD_OFframe_37.jpeg
# S3_wavingHands_HD_OFframe_38.jpeg
# S3_wavingHands_HD_OFframe_39.jpeg
# S3_wavingHands_HD_OFframe_40.jpeg
# S3_wavingHands_HD_OFframe_41.jpeg
# S3_wavingHands_HD_OFframe_42.jpeg
# S3_wavingHands_HD_OFframe_43.jpeg
# S3_wavingHands_HD_OFframe_44.jpeg
# S3_wavingHands_HD_OFframe_45.jpeg
# S3_wavingHands_HD_OFframe_46.jpeg
# S3_wavingHands_HD_OFframe_47.jpeg
# S3_wavingHands_HD_OFframe_48.jpeg
# S3_wavingHands_HD_OFframe_49.jpeg
# computing OF in S1_wavingHands_HD
# S1_wavingHands_HD_OFframe_0.jpeg
# creating directory datasets/OF/waving_hands/S1_wavingHands_HD
# S1_wavingHands_HD_OFframe_1.jpeg
# S1_wavingHands_HD_OFframe_2.jpeg
# S1_wavingHands_HD_OFframe_3.jpeg
# S1_wavingHands_HD_OFframe_4.jpeg
# S1_wavingHands_HD_OFframe_5.jpeg
# S1_wavingHands_HD_OFframe_6.jpeg
# S1_wavingHands_HD_OFframe_7.jpeg
# S1_wavingHands_HD_OFframe_8.jpeg
# S1_wavingHands_HD_OFframe_9.jpeg
# S1_wavingHands_HD_OFframe_10.jpeg
# S1_wavingHands_HD_OFframe_11.jpeg
# S1_wavingHands_HD_OFframe_12.jpeg
# S1_wavingHands_HD_OFframe_13.jpeg
# S1_wavingHands_HD_OFframe_14.jpeg
# S1_wavingHands_HD_OFframe_15.jpeg
# S1_wavingHands_HD_OFframe_16.jpeg
# S1_wavingHands_HD_OFframe_17.jpeg
# S1_wavingHands_HD_OFframe_18.jpeg
# S1_wavingHands_HD_OFframe_19.jpeg
# S1_wavingHands_HD_OFframe_20.jpeg
# S1_wavingHands_HD_OFframe_21.jpeg
# S1_wavingHands_HD_OFframe_22.jpeg
# S1_wavingHands_HD_OFframe_23.jpeg
# S1_wavingHands_HD_OFframe_24.jpeg
# S1_wavingHands_HD_OFframe_25.jpeg
# S1_wavingHands_HD_OFframe_26.jpeg
# S1_wavingHands_HD_OFframe_27.jpeg
# S1_wavingHands_HD_OFframe_28.jpeg
# S1_wavingHands_HD_OFframe_29.jpeg
# S1_wavingHands_HD_OFframe_30.jpeg
# S1_wavingHands_HD_OFframe_31.jpeg
# S1_wavingHands_HD_OFframe_32.jpeg
# S1_wavingHands_HD_OFframe_33.jpeg
# S1_wavingHands_HD_OFframe_34.jpeg
# S1_wavingHands_HD_OFframe_35.jpeg
# S1_wavingHands_HD_OFframe_36.jpeg
# S1_wavingHands_HD_OFframe_37.jpeg
# S1_wavingHands_HD_OFframe_38.jpeg
# S1_wavingHands_HD_OFframe_39.jpeg
# S1_wavingHands_HD_OFframe_40.jpeg
# S1_wavingHands_HD_OFframe_41.jpeg
# S1_wavingHands_HD_OFframe_42.jpeg
# S1_wavingHands_HD_OFframe_43.jpeg
# S1_wavingHands_HD_OFframe_44.jpeg
# S1_wavingHands_HD_OFframe_45.jpeg
# S1_wavingHands_HD_OFframe_46.jpeg
# S1_wavingHands_HD_OFframe_47.jpeg
# S1_wavingHands_HD_OFframe_48.jpeg
# S1_wavingHands_HD_OFframe_49.jpeg
